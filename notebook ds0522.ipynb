# %%
print("hello world")
# Out:
# hello world

# %%
print("kamran ashraf")
# Out:
# kamran ashraf

# %%
x=10
y="kamran"
print(f"the value of x is {x} and the value of y is {y}")
# Out:
# the value of x is 10 and the value of y is kamran
